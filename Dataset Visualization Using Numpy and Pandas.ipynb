# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('/home/smritiyadav20075933/ml-master/company_employee_details.csv')

# %%
print(df.head())
# Out:
#    Unnamed: 0   company     department  employee_id  age  age_when_joined  \
# 0           0   Glasses        BigData           16   41               38
# 1           1   Glasses             AI           56   44               42
# 2           2  Cheerper        Support           59   41               40
# 3           3   Glasses         Design           40   39               32
# 4           4   Glasses  Search Engine           47   30               22
#
#    years_in_the_company         salary  annual_bonus  prior_years_experience  \
# 0                     3   68074.971354  17664.104103                       3
# 1                     2   49092.147458  21551.141079                       2
# 2                     1   40000.000000  23698.878851                       2
# 3                     7  108192.465506  21570.929657                       1
# 4                     9   71291.191132  21565.505715                       2
#
#    full_time  part_time  contractor
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'company', 'department', 'employee_id', 'age',
#        'age_when_joined', 'years_in_the_company', 'salary', 'annual_bonus',
#        'prior_years_experience', 'full_time', 'part_time', 'contractor'],
#       dtype='object')

# %%
plt.scatter(df['age_when_joined'],df['years_in_the_company'],alpha=0.5)
plt.xlabel('age_when_joined')
plt.ylabel('years_in_the_company')
plt.title('Scatter plot')
plt.show()
records_num=len(df)
print("Total number of records is:5000")
# Out:
# Total number of records is:5000

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = df['years_in_the_company']  
y = df['age_when_joined']  
plt.xlabel('age_when_joined')
plt.ylabel('years_in_the_company')
plt.title('bar plot')
plt.bar(x,y)#bar plot
print("Total number of records is:5000")
# Out:
# Total number of records is:5000

# %%
plt.bar(x,y)#bar plot
# Out:
# <BarContainer object of 5000 artists>

# %%
records_num=len()

# %%
x = df['years_in_the_company']  
y = df['age_when_joined']  
plt.xlabel('age_when_joined')
plt.ylabel('years_in_the_company')
plt.title('line plot')
plt.plot(x,y)#line plot
